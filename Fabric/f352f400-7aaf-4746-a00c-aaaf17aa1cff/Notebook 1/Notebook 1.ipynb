# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

df = spark.sql("SELECT * FROM MyLake.TaxiGreen LIMIT 1000")
display(df)
# Out:
# StatementMeta(, d1d32435-ed62-46ad-afb3-721ff132032e, 3, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 8440a97b-8e89-46c4-b682-28df3475155e)

# %%
df = spark.sql("SELECT * FROM MyLake.TaxiGreen LIMIT 1000")
display(df)
